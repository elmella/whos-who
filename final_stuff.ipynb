# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
import warnings
import string
import re
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import umap
import ast

pd.options.mode.chained_assignment = None

# %%
def get_transition_matrix_efficient(df, word_to_index, d, initial_values=1):
    transition_counts = np.ones((d, d), dtype=int) * initial_values
    for utterance in df['utterance']:
        if type(utterance) != str:
            try:
                utterance = str(utterance)
            except:
                continue
        words = utterance.split()
        for i in range(1, len(words)):
            word1 = words[i - 1]
            word2 = words[i]
            if word1 in word_to_index and word2 in word_to_index:
                index1 = word_to_index[word1]
                index2 = word_to_index[word2]
                transition_counts[index2, index1] += 1
    column_sums = transition_counts.sum(axis=0, keepdims=True)
    transition_probabilities = transition_counts / column_sums
    return transition_probabilities, word_to_index

def tensor_trouble(df, word_to_index, d, initial_values=1):
    tensor = np.ones((d, 2, 2), dtype=int) * initial_values
    for episode, group in df.groupby('episode'):
        if type(group['utterance']) != str:
            group['utterance'] = group['utterance'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
        text = " ".join(group['utterance'].astype(str))
        words = text.split()
        roles = np.concatenate(group.apply(lambda row: [row['is_host']] * len(str(row['utterance']).split()), axis=1).values)
        for i in range(2, len(words)):
            word = words[i - 2]
            if word not in word_to_index:  # Check if the word exists in the dictionary
                continue  # Skip this iteration if the word is not found

            # get the roles of the current word and the next two words
            next_role = roles[i - 1]
            following_role = roles[i]

            # get the index of the current word
            current_index = word_to_index[word]

            # get the index of the roles
            current_role_index = 0 if next_role else 1
            next_role_index = 0 if following_role else 1

            
            tensor[current_index, next_role_index, current_role_index] += 1
    return tensor, word_to_index

def make_emission(host, guest):
    emission = np.zeros((len(host), len(host), 2))
    emission[:, :, 0] = host
    emission[:, :, 1] = guest
    return np.swapaxes(emission, 0, 1)

def tensor_viterbi(obs, transition, emission, initial):
    b_eps = 1e-25
    start_index = obs[0]
    obs = obs[1:]
    n = len(obs)
    d = transition.shape[0]
    eta = np.zeros((n, 2))
    backpointers = np.zeros((n, 2), dtype=int)
    eta[0] = np.log(initial) + np.log(emission[start_index, obs[1], :])
    obs = obs[1:]
    for i in range(1, n - 1):
        b = emission[obs[i - 1], obs[i], :]
        if np.any(b == 0):
            zero_index = np.where(b == 0)
            b[zero_index] = b_eps
        eta_candidate = np.log(transition[obs[i - 1], :, :]) + np.log(b)[:, np.newaxis] + eta[i - 1][np.newaxis, :]
        eta[i] = np.max(eta_candidate, axis=1)
        backpointers[i] = np.argmax(eta_candidate, axis=1)
    state_sequence = np.zeros(n, dtype=int)
    state_sequence[-1] = np.argmax(eta[-1])
    for i in range(n - 2, -1, -1):
        state_sequence[i] = backpointers[i + 1, state_sequence[i + 1]]
    return state_sequence

def pad_to_match(a, b):
    """
    Pads the shorter array with its last element to match the length of the longer array.
    
    Args:
        a (np.array): First array for comparison.
        b (np.array): Second array for comparison.
        
    Returns:
        np.array, np.array: The two arrays modified to have equal lengths.
    """
    if len(a) == len(b):
        return a, b
    elif len(a) > len(b):
        padding = np.full(len(a) - len(b), b[-1])
        b_padded = np.concatenate((b, padding))
        return a, b_padded
    else:
        padding = np.full(len(b) - len(a), a[-1])
        a_padded = np.concatenate((a, padding))
        return a_padded, b
    
def filter_episodes(df, host_id=None):
    df_filtered = df[df['host_id'] != -1]
    if host_id is None:
        top_host = df_filtered.groupby('host_id')['episode'].nunique().idxmax()
    else:
        top_host = host_id
    top_host_episodes = df_filtered[df_filtered['host_id'] == top_host]['episode'].unique()
    df_top_host_all_utterances = df[df['episode'].isin(top_host_episodes)]
    utterance_counts = df_top_host_all_utterances.groupby('episode')['utterance'].count()
    episodes_over_30 = utterance_counts[utterance_counts > 30].index
    df_top_host_over_30 = df_top_host_all_utterances[df_top_host_all_utterances['episode'].isin(episodes_over_30)]
    return df_top_host_over_30.reset_index(drop=True)

# %%
test_size = 0.2
embedding_path = 'archive/embed_df_with_hosts_filtered.csv'
utterance_path = 'archive/processed_utterances-2sp.csv'
umap_components = 10
initial_state_probabilities = np.array([.5, .5])

# Load the data
episode_embedding_df = pd.read_csv('archive/embed_df_with_hosts.csv')

# get the host_ids that have at least 100 episodes
host_ids = episode_embedding_df['host_id'].value_counts()[episode_embedding_df['host_id'].value_counts() > 100].index

episode_embedding_df = episode_embedding_df[episode_embedding_df['host_id'].isin(host_ids)]
# Convert the string into a list and then into an array of floats
episode_embedding_df['embedding'] = episode_embedding_df['embedding'].apply(lambda x: np.array(ast.literal_eval(x)))
utterance_df = pd.read_csv(utterance_path)

# %%
# get the number of unique hosts
host_ids = episode_embedding_df['host_id'].unique()
n_components = len(host_ids) // 4

episodes = episode_embedding_df['episode'].unique()
np.random.shuffle(episodes)
split_index = int(len(episodes) * 0.8)
train_episodes = episodes[:split_index]
test_episodes = episodes[split_index:]


X_train = episode_embedding_df[episode_embedding_df['episode'].isin(train_episodes)]['embedding']
X_test = episode_embedding_df[episode_embedding_df['episode'].isin(test_episodes)]['embedding']
y_train = episode_embedding_df[episode_embedding_df['episode'].isin(train_episodes)]['host_id']
y_test = episode_embedding_df[episode_embedding_df['episode'].isin(test_episodes)]['host_id']

# Convert the labels to integers
y_train = y_train.astype(int)
y_test = y_test.astype(int)

# Convert the lists of floats into numpy arrays
X_train = np.array([np.array(x) for x in X_train])
X_test = np.array([np.array(x) for x in X_test])
# Reduce dimensions to 20 with UMAP
umap_reducer = umap.UMAP(n_components=umap_components)
X_reduced = umap_reducer.fit_transform(X_train)


print(f"Fitting GMM with {n_components} components")
gmm = GaussianMixture(n_components=n_components)
gmm.fit(X_reduced)

# Predict cluster labels
train_cluster_labels = gmm.predict(X_reduced)

# reduce the dimensions of the test set
X_test_reduced = umap_reducer.transform(X_test)

# Predict the cluster labels of the test set
test_cluster_labels = gmm.predict(X_test_reduced)

# # create dictionary to map train cluster labels to embeddings
train_cluster_to_embedding = {cluster: [] for cluster in set(train_cluster_labels)}
for cluster, embedding in zip(train_cluster_labels, X_train):
    train_cluster_to_embedding[cluster].append(embedding)

# create dictionary to map embeddings to episode ids
embedding_to_episode = {tuple(embedding): episode for embedding, episode in zip(episode_embedding_df['embedding'], episode_embedding_df['episode'])}

# create dictionary to map train cluster labels to episoded ids
train_cluster_to_episode = {cluster: [] for cluster in set(train_cluster_labels)}
for cluster, embedding in zip(train_cluster_labels, X_train):
    train_cluster_to_episode[cluster].append(embedding_to_episode[tuple(embedding)])

# create dictionary to map test cluster labels to embeddings
test_cluster_to_embedding = {cluster: [] for cluster in set(test_cluster_labels)}
for cluster, embedding in zip(test_cluster_labels, X_test):
    test_cluster_to_embedding[cluster].append(embedding)


# create dictionary to map test cluster labels to episoded ids
test_cluster_to_episode = {cluster: [] for cluster in set(test_cluster_labels)}
for cluster, embedding in zip(test_cluster_labels, X_test):
    test_cluster_to_episode[cluster].append(embedding_to_episode[tuple(embedding)])
# Out:
# Fitting GMM with 8 components

# %%
results_dict = {episode: [] for episode in episode_embedding_df[episode_embedding_df['episode'].isin(test_episodes)]['episode'].unique()}

# Iterate through each unique test cluster label
for cluster in set(test_cluster_labels):
    print(f"Cluster {cluster}")
    # Get the embeddings of the cluster
    cluster_embeddings = test_cluster_to_embedding[cluster]
    # Get the episode ids of the test episodes in the cluster
    cluster_test_episodes = test_cluster_to_episode[cluster]

    # Get the episode ids of the train episodes in the cluster
    cluster_train_episodes = train_cluster_to_episode[cluster]

    # Filter the utterance df to only include the episodes in the cluster for training and testing
    filtered_df = utterance_df[utterance_df['episode'].isin(cluster_train_episodes + cluster_test_episodes)][['is_host', 'episode', 'utterance']]

    # Split each utterance into a list of words and explode the DataFrame to get a row per word
    words_series = filtered_df['utterance'].str.split().explode()
    unique_words = set(words_series)
    word_frequencies = words_series.value_counts().to_dict()
    word_indices = {word: i for i, word in enumerate(unique_words)}

    # Filter the filter df to only include the episodes in the cluster for training and testing
    training_df = filtered_df[filtered_df['episode'].isin(cluster_train_episodes)]
    testing_df = filtered_df[filtered_df['episode'].isin(cluster_test_episodes)]

    print(len(training_df))
    print(len(testing_df))

    # Get the transition matrix for the training data
    transition_matrix_host, word_to_index_host = get_transition_matrix_efficient(training_df[training_df['is_host'] == True], word_indices, len(unique_words))
    transition_matrix_guest, word_to_index_guest = get_transition_matrix_efficient(training_df[training_df['is_host'] == False], word_indices, len(unique_words))

    # Get the tensor for the training data
    tensor, word_to_index = tensor_trouble(training_df, word_indices, len(unique_words))

    # Normalize the tensor
    tensor_normalized = tensor / (tensor.sum(axis=1, keepdims=True))

    # Get the emission matrix for the training data
    emission_matrix = make_emission(transition_matrix_host, transition_matrix_guest)

    for episode in cluster_test_episodes:
        test_episode_df = testing_df[testing_df['episode'] == episode]
        test_episode_df['utterance'] = test_episode_df['utterance'].str.split()
        test_episode_df = test_episode_df.explode('utterance')
        test_label = test_episode_df['is_host'].to_numpy().astype(int)
        test_episode_words = ' '.join(test_episode_df['utterance'].astype(str)).split()
        test_episode_words = [word for word in test_episode_words if word != 'nan']
        test_episode_word_indices = [word_indices.get(word, -1) for word in test_episode_words if word in word_indices]
        obs = [0] + test_episode_word_indices  # Add start token index (e.g., 0) if your Viterbi expects it



        state_sequence = tensor_viterbi(obs, tensor_normalized, emission_matrix, initial_state_probabilities)
        # print(len(state_sequence))
        test_label_padded, state_sequence_padded = pad_to_match(test_label, state_sequence)

        # Now, calculate the accuracy
        accuracy = np.mean((state_sequence_padded == test_label_padded).astype(int))

        # Switch the labels if accuracy is less than 0.5
        if accuracy < 0.5:
            accuracy = 1 - accuracy
            state_sequence_padded = 1 - state_sequence_padded
        
        assume_0 = (test_label_padded == 1).astype(int)
        assume_0_accuracy = np.mean(assume_0)

        # Switch the labels if accuracy is less than 0.5
        if assume_0_accuracy < 0.5:
            assume_0_accuracy = 1 - assume_0_accuracy
            assume_0 = 1 - assume_0

        # Calculate the confusion matrices
        confusion = confusion_matrix(test_label_padded, state_sequence_padded)
        assume_0_confusion = confusion_matrix(test_label_padded, assume_0)

        # Append the confusion matrices to the results dictionary
        results_dict[episode].append({
            'accuracy': accuracy,
            'confusion': confusion,
            'assume_0_accuracy': assume_0_accuracy,
            'assume_0_confusion': assume_0_confusion,
            'method': 'Clustering'
        })

for host_id in utterance_df['host_id'].unique():
    print(f"Host {host_id}")
    # Filter the utterance and embedding dataframes for this specific host
    host_utterance_df = filter_episodes(utterance_df, host_id=host_id)

    # Get the episodes related to this host
    host_episodes = host_utterance_df['episode'].unique()

    # Process the utterances as before
    words_series = host_utterance_df['utterance'].str.split().explode()
    unique_words = set(words_series)
    word_frequencies = words_series.value_counts().to_dict()
    word_indices = {word: i for i, word in enumerate(unique_words)}
    
    

    training_df = host_utterance_df[host_utterance_df['episode'].isin(train_episodes)]
    print(len(training_df))
    testing_df = host_utterance_df[host_utterance_df['episode'].isin(test_episodes)]
    print(len(testing_df))

    # Calculate transition matrices and tensor for training data
    transition_matrix_host, word_to_index_host = get_transition_matrix_efficient(training_df[training_df['is_host'] == True], word_indices, len(unique_words))
    transition_matrix_guest, word_to_index_guest = get_transition_matrix_efficient(training_df[training_df['is_host'] == False], word_indices, len(unique_words))
    tensor, word_to_index = tensor_trouble(training_df, word_indices, len(unique_words))
    tensor_normalized = tensor / (tensor.sum(axis=1, keepdims=True))

    # Emission matrix for training data
    emission_matrix = make_emission(transition_matrix_host, transition_matrix_guest)


    for episode in testing_df['episode'].unique():
        test_episode_df = testing_df[testing_df['episode'] == episode][['is_host', 'utterance']]
        test_episode_df['utterance'] = test_episode_df['utterance'].str.split()
        test_episode_df = test_episode_df.explode('utterance')
        test_label = test_episode_df['is_host'].to_numpy().astype(int)
        test_episode_words = ' '.join(test_episode_df['utterance'].astype(str)).split()
        test_episode_words = [word for word in test_episode_words if word != 'nan']
        test_episode_word_indices = [word_indices.get(word, -1) for word in test_episode_words if word in word_indices]
        if not test_episode_word_indices:  # If the list is empty, skip to the next iteration
            print(f"No words processed for episode {episode}, skipping...")
            continue
        obs = [0] + test_episode_word_indices  # Include start token

        state_sequence = tensor_viterbi(obs, tensor_normalized, emission_matrix, initial_state_probabilities)
        test_label_padded, state_sequence_padded = pad_to_match(test_label, state_sequence)

        accuracy = np.mean((state_sequence_padded == test_label_padded).astype(int))

        if accuracy < 0.5:
            accuracy = 1 - accuracy
            state_sequence_padded = 1 - state_sequence_padded

        assume_0 = (test_label_padded == 1).astype(int)
        assume_0_accuracy = np.mean(assume_0)

        if assume_0_accuracy < 0.5:
            assume_0_accuracy = 1 - assume_0_accuracy
            assume_0 = 1 - assume_0

        confusion = confusion_matrix(test_label_padded, state_sequence_padded)
        assume_0_confusion = confusion_matrix(test_label_padded, assume_0)

        if episode not in results_dict or 'Host' not in [result['method'] for result in results_dict[episode]]:
            results_dict[episode].append({
                'accuracy': accuracy,
                'confusion': confusion,
                'assume_0_accuracy': assume_0_accuracy,
                'assume_0_confusion': assume_0_confusion,
                'method': 'Host'
            })
        else:
            print(f"Duplicate or existing entry found for episode {episode} under Host method.")

# Save the results dictionary to a file
with open('archive/results_dict.json', 'w') as f:
    f.write(str(results_dict))
# Out:
# Cluster 0
# 37692
# 9164
# Cluster 1
# 70125
# 18422
# Cluster 2
# 93467
# 23342
# Cluster 3
# 230424
# 54414

# %%
results_dict
# Out:
# {67: [{'accuracy': 0.8785249457700651,
#    'confusion': array([[384,   3],
#           [ 53,  21]]),
#    'assume_0_accuracy': 0.8394793926247288,
#    'assume_0_confusion': array([[  0, 387],
#           [ 74,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.8064516129032258,
#    'confusion': array([[23,  1],
#           [ 5,  2]]),
#    'assume_0_accuracy': 0.7741935483870968,
#    'assume_0_confusion': array([[ 0, 24],
#           [ 7,  0]]),
#    'method': 'Host'}],
#  109: [{'accuracy': 0.8888888888888888,
#    'confusion': array([[480,   6],
#           [ 57,  24]]),
#    'assume_0_accuracy': 0.8571428571428572,
#    'assume_0_confusion': array([[  0, 486],
#           [ 81,   0]]),
#    'method': 'Clustering'}],
#  112: [{'accuracy': 0.7964601769911505,
#    'confusion': array([[791,   7],
#           [200,  19]]),
#    'assume_0_accuracy': 0.7846607669616519,
#    'assume_0_confusion': array([[  0, 798],
#           [219,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6551724137931034,
#    'confusion': array([[37,  1],
#           [19,  1]]),
#    'assume_0_accuracy': 0.6551724137931034,
#    'assume_0_confusion': array([[ 0, 38],
#           [20,  0]]),
#    'method': 'Host'}],
#  137: [{'accuracy': 0.7399425287356323,
#    'confusion': array([[507,   2],
#           [179,   8]]),
#    'assume_0_accuracy': 0.7313218390804598,
#    'assume_0_confusion': array([[  0, 509],
#           [187,   0]]),
#    'method': 'Clustering'}],
#  138: [{'accuracy': 0.8309608540925266,
#    'confusion': array([[441,  10],
#           [ 85,  26]]),
#    'assume_0_accuracy': 0.802491103202847,
#    'assume_0_confusion': array([[  0, 451],
#           [111,   0]]),
#    'method': 'Clustering'}],
#  140: [{'accuracy': 0.75,
#    'confusion': array([[354,   5],
#           [119,  18]]),
#    'assume_0_accuracy': 0.7237903225806452,
#    'assume_0_confusion': array([[  0, 359],
#           [137,   0]]),
#    'method': 'Clustering'}],
#  149: [{'accuracy': 0.8401109057301294,
#    'confusion': array([[891,   2],
#           [171,  18]]),
#    'assume_0_accuracy': 0.8253234750462107,
#    'assume_0_confusion': array([[  0, 893],
#           [189,   0]]),
#    'method': 'Clustering'}],
#  160: [{'accuracy': 0.784471218206158,
#    'confusion': array([[564,   4],
#           [157,  22]]),
#    'assume_0_accuracy': 0.7603748326639893,
#    'assume_0_confusion': array([[  0, 568],
#           [179,   0]]),
#    'method': 'Clustering'}],
#  177: [{'accuracy': 0.8176691729323309,
#    'confusion': array([[386,   3],
#           [ 94,  49]]),
#    'assume_0_accuracy': 0.731203007518797,
#    'assume_0_confusion': array([[  0, 389],
#           [143,   0]]),
#    'method': 'Clustering'}],
#  194: [{'accuracy': 0.732843137254902,
#    'confusion': array([[271,   2],
#           [107,  28]]),
#    'assume_0_accuracy': 0.6691176470588236,
#    'assume_0_confusion': array([[  0, 273],
#           [135,   0]]),
#    'method': 'Clustering'}],
#  208: [{'accuracy': 0.9191729323308271,
#    'confusion': array([[461,   2],
#           [ 41,  28]]),
#    'assume_0_accuracy': 0.8703007518796992,
#    'assume_0_confusion': array([[  0, 463],
#           [ 69,   0]]),
#    'method': 'Clustering'}],
#  241: [{'accuracy': 0.8379052369077307,
#    'confusion': array([[330,   2],
#           [ 63,   6]]),
#    'assume_0_accuracy': 0.827930174563591,
#    'assume_0_confusion': array([[  0, 332],
#           [ 69,   0]]),
#    'method': 'Clustering'}],
#  269: [{'accuracy': 0.821173104434907,
#    'confusion': array([[525,  12],
#           [113,  49]]),
#    'assume_0_accuracy': 0.7682403433476395,
#    'assume_0_confusion': array([[  0, 537],
#           [162,   0]]),
#    'method': 'Clustering'}],
#  272: [{'accuracy': 0.803921568627451,
#    'confusion': array([[419,   4],
#           [106,  32]]),
#    'assume_0_accuracy': 0.7540106951871658,
#    'assume_0_confusion': array([[  0, 423],
#           [138,   0]]),
#    'method': 'Clustering'}],
#  284: [{'accuracy': 0.6538461538461539,
#    'confusion': array([[387,   5],
#           [211,  21]]),
#    'assume_0_accuracy': 0.6282051282051282,
#    'assume_0_confusion': array([[  0, 392],
#           [232,   0]]),
#    'method': 'Clustering'}],
#  286: [{'accuracy': 0.87701317715959,
#    'confusion': array([[578,   3],
#           [ 81,  21]]),
#    'assume_0_accuracy': 0.8506588579795022,
#    'assume_0_confusion': array([[  0, 581],
#           [102,   0]]),
#    'method': 'Clustering'}],
#  326: [{'accuracy': 0.7946611909650925,
#    'confusion': array([[363,   9],
#           [ 91,  24]]),
#    'assume_0_accuracy': 0.7638603696098563,
#    'assume_0_confusion': array([[  0, 372],
#           [115,   0]]),
#    'method': 'Clustering'}],
#  367: [{'accuracy': 0.8514680483592401,
#    'confusion': array([[460,   3],
#           [ 83,  33]]),
#    'assume_0_accuracy': 0.7996545768566494,
#    'assume_0_confusion': array([[  0, 463],
#           [116,   0]]),
#    'method': 'Clustering'}],
#  400: [{'accuracy': 0.7323943661971831,
#    'confusion': array([[348,   2],
#           [131,  16]]),
#    'assume_0_accuracy': 0.704225352112676,
#    'assume_0_confusion': array([[  0, 350],
#           [147,   0]]),
#    'method': 'Clustering'}],
#  404: [{'accuracy': 0.7070135746606334,
#    'confusion': array([[596,   2],
#           [257,  29]]),
#    'assume_0_accuracy': 0.6764705882352942,
#    'assume_0_confusion': array([[  0, 598],
#           [286,   0]]),
#    'method': 'Clustering'}],
#  421: [{'accuracy': 0.7925407925407926,
#    'confusion': array([[316,  11],
#           [ 78,  24]]),
#    'assume_0_accuracy': 0.7622377622377623,
#    'assume_0_confusion': array([[  0, 327],
#           [102,   0]]),
#    'method': 'Clustering'}],
#  424: [{'accuracy': 0.5256410256410257,
#    'confusion': array([[67,  0],
#           [74, 15]]),
#    'assume_0_accuracy': 0.5705128205128205,
#    'assume_0_confusion': array([[67,  0],
#           [ 0, 89]]),
#    'method': 'Clustering'}],
#  433: [{'accuracy': 0.6684684684684685,
#    'confusion': array([[300,  21],
#           [163,  71]]),
#    'assume_0_accuracy': 0.5783783783783784,
#    'assume_0_confusion': array([[  0, 321],
#           [234,   0]]),
#    'method': 'Clustering'}],
#  439: [{'accuracy': 0.6656746031746033,
#    'confusion': array([[660,   2],
#           [335,  11]]),
#    'assume_0_accuracy': 0.6567460317460317,
#    'assume_0_confusion': array([[  0, 662],
#           [346,   0]]),
#    'method': 'Clustering'}],
#  464: [{'accuracy': 0.6077057793345009,
#    'confusion': array([[339,   4],
#           [220,   8]]),
#    'assume_0_accuracy': 0.6007005253940456,
#    'assume_0_confusion': array([[  0, 343],
#           [228,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.5660377358490566,
#    'confusion': array([[20, 11],
#           [12, 10]]),
#    'assume_0_accuracy': 0.5849056603773585,
#    'assume_0_confusion': array([[ 0, 31],
#           [22,  0]]),
#    'method': 'Host'}],
#  471: [{'accuracy': 0.7712833545108005,
#    'confusion': array([[554,   8],
#           [172,  53]]),
#    'assume_0_accuracy': 0.7141041931385006,
#    'assume_0_confusion': array([[  0, 562],
#           [225,   0]]),
#    'method': 'Clustering'}],
#  482: [{'accuracy': 0.6084724005134788,
#    'confusion': array([[423,   8],
#           [297,  51]]),
#    'assume_0_accuracy': 0.5532734274711169,
#    'assume_0_confusion': array([[  0, 431],
#           [348,   0]]),
#    'method': 'Clustering'}],
#  494: [{'accuracy': 0.8845577211394303,
#    'confusion': array([[567,   2],
#           [ 75,  23]]),
#    'assume_0_accuracy': 0.8530734632683659,
#    'assume_0_confusion': array([[  0, 569],
#           [ 98,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.7555555555555555,
#    'confusion': array([[33,  4],
#           [ 7,  1]]),
#    'assume_0_accuracy': 0.8222222222222222,
#    'assume_0_confusion': array([[ 0, 37],
#           [ 8,  0]]),
#    'method': 'Host'}],
#  503: [{'accuracy': 0.7090592334494774,
#    'confusion': array([[358,   5],
#           [162,  49]]),
#    'assume_0_accuracy': 0.632404181184669,
#    'assume_0_confusion': array([[  0, 363],
#           [211,   0]]),
#    'method': 'Clustering'}],
#  512: [{'accuracy': 0.764,
#    'confusion': array([[318,   7],
#           [111,  64]]),
#    'assume_0_accuracy': 0.65,
#    'assume_0_confusion': array([[  0, 325],
#           [175,   0]]),
#    'method': 'Clustering'}],
#  513: [{'accuracy': 0.956989247311828,
#    'confusion': array([[429,   0],
#           [ 20,  16]]),
#    'assume_0_accuracy': 0.9225806451612903,
#    'assume_0_confusion': array([[  0, 429],
#           [ 36,   0]]),
#    'method': 'Clustering'}],
#  515: [{'accuracy': 0.8191780821917808,
#    'confusion': array([[576,   6],
#           [126,  22]]),
#    'assume_0_accuracy': 0.7972602739726027,
#    'assume_0_confusion': array([[  0, 582],
#           [148,   0]]),
#    'method': 'Clustering'}],
#  615: [{'accuracy': 0.7651209677419355,
#    'confusion': array([[729,  11],
#           [222,  30]]),
#    'assume_0_accuracy': 0.7459677419354839,
#    'assume_0_confusion': array([[  0, 740],
#           [252,   0]]),
#    'method': 'Clustering'}],
#  630: [{'accuracy': 0.7816725087631448,
#    'confusion': array([[1432,    4],
#           [ 432,  129]]),
#    'assume_0_accuracy': 0.7190786179268903,
#    'assume_0_confusion': array([[   0, 1436],
#           [ 561,    0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6703296703296704,
#    'confusion': array([[58,  0],
#           [30,  3]]),
#    'assume_0_accuracy': 0.6373626373626373,
#    'assume_0_confusion': array([[ 0, 58],
#           [33,  0]]),
#    'method': 'Host'}],
#  737: [{'accuracy': 0.6929032258064516,
#    'confusion': array([[504,   4],
#           [234,  33]]),
#    'assume_0_accuracy': 0.655483870967742,
#    'assume_0_confusion': array([[  0, 508],
#           [267,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.5087719298245614,
#    'confusion': array([[28,  4],
#           [24,  1]]),
#    'assume_0_accuracy': 0.5614035087719298,
#    'assume_0_confusion': array([[ 0, 32],
#           [25,  0]]),
#    'method': 'Host'}],
#  749: [{'accuracy': 0.8374558303886925,
#    'confusion': array([[435,   3],
#           [ 89,  39]]),
#    'assume_0_accuracy': 0.773851590106007,
#    'assume_0_confusion': array([[  0, 438],
#           [128,   0]]),
#    'method': 'Clustering'}],
#  841: [{'accuracy': 0.9927797833935018,
#    'confusion': array([[246,   0],
#           [  2,  29]]),
#    'assume_0_accuracy': 0.8880866425992779,
#    'assume_0_confusion': array([[  0, 246],
#           [ 31,   0]]),
#    'method': 'Clustering'}],
#  844: [{'accuracy': 0.8641618497109826,
#    'confusion': array([[286,   0],
#           [ 47,  13]]),
#    'assume_0_accuracy': 0.8265895953757225,
#    'assume_0_confusion': array([[  0, 286],
#           [ 60,   0]]),
#    'method': 'Clustering'}],
#  846: [{'accuracy': 0.8082901554404145,
#    'confusion': array([[546,   2],
#           [146,  78]]),
#    'assume_0_accuracy': 0.7098445595854923,
#    'assume_0_confusion': array([[  0, 548],
#           [224,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.7307692307692308,
#    'confusion': array([[36,  0],
#           [14,  2]]),
#    'assume_0_accuracy': 0.6923076923076923,
#    'assume_0_confusion': array([[ 0, 36],
#           [16,  0]]),
#    'method': 'Host'}],
#  882: [{'accuracy': 0.7704918032786885,
#    'confusion': array([[472,   4],
#           [150,  45]]),
#    'assume_0_accuracy': 0.7093889716840536,
#    'assume_0_confusion': array([[  0, 476],
#           [195,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6428571428571428,
#    'confusion': array([[35,  1],
#           [19,  1]]),
#    'assume_0_accuracy': 0.6428571428571428,
#    'assume_0_confusion': array([[ 0, 36],
#           [20,  0]]),
#    'method': 'Host'}],
#  888: [{'accuracy': 0.6839577329490873,
#    'confusion': array([[619,   9],
#           [320,  93]]),
#    'assume_0_accuracy': 0.6032660902977907,
#    'assume_0_confusion': array([[  0, 628],
#           [413,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.625,
#    'confusion': array([[51,  4],
#           [29,  4]]),
#    'assume_0_accuracy': 0.625,
#    'assume_0_confusion': array([[ 0, 55],
#           [33,  0]]),
#    'method': 'Host'}],
#  915: [{'accuracy': 0.6985195154777928,
#    'confusion': array([[444,  12],
#           [212,  75]]),
#    'assume_0_accuracy': 0.613728129205922,
#    'assume_0_confusion': array([[  0, 456],
#           [287,   0]]),
#    'method': 'Clustering'}],
#  922: [{'accuracy': 0.5973282442748091,
#    'confusion': array([[912,   4],
#           [629,  27]]),
#    'assume_0_accuracy': 0.5826972010178118,
#    'assume_0_confusion': array([[  0, 916],
#           [656,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.5546875,
#    'confusion': array([[67,  4],
#           [53,  4]]),
#    'assume_0_accuracy': 0.5546875,
#    'assume_0_confusion': array([[ 0, 71],
#           [57,  0]]),
#    'method': 'Host'}],
#  926: [{'accuracy': 0.6803394625176804,
#    'confusion': array([[419,  26],
#           [200,  62]]),
#    'assume_0_accuracy': 0.6294200848656295,
#    'assume_0_confusion': array([[  0, 445],
#           [262,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6052631578947368,
#    'confusion': array([[20,  2],
#           [13,  3]]),
#    'assume_0_accuracy': 0.5789473684210527,
#    'assume_0_confusion': array([[ 0, 22],
#           [16,  0]]),
#    'method': 'Host'}],
#  956: [{'accuracy': 0.7989690721649485,
#    'confusion': array([[499,  14],
#           [142, 121]]),
#    'assume_0_accuracy': 0.6610824742268041,
#    'assume_0_confusion': array([[  0, 513],
#           [263,   0]]),
#    'method': 'Clustering'}],
#  966: [{'accuracy': 0.7185354691075515,
#    'confusion': array([[881,   3],
#           [366,  61]]),
#    'assume_0_accuracy': 0.6742944317315027,
#    'assume_0_confusion': array([[  0, 884],
#           [427,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.7241379310344828,
#    'confusion': array([[60,  0],
#           [24,  3]]),
#    'assume_0_accuracy': 0.6896551724137931,
#    'assume_0_confusion': array([[ 0, 60],
#           [27,  0]]),
#    'method': 'Host'}],
#  974: [{'accuracy': 0.7797619047619048,
#    'confusion': array([[1009,    6],
#           [ 290,   39]]),
#    'assume_0_accuracy': 0.7552083333333334,
#    'assume_0_confusion': array([[   0, 1015],
#           [ 329,    0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.7301587301587302,
#    'confusion': array([[44,  0],
#           [17,  2]]),
#    'assume_0_accuracy': 0.6984126984126984,
#    'assume_0_confusion': array([[ 0, 44],
#           [19,  0]]),
#    'method': 'Host'}],
#  1029: [{'accuracy': 0.8449074074074074,
#    'confusion': array([[2733,   10],
#           [ 526,  187]]),
#    'assume_0_accuracy': 0.7936921296296297,
#    'assume_0_confusion': array([[   0, 2743],
#           [ 713,    0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.7654320987654322,
#    'confusion': array([[182,   4],
#           [ 53,   4]]),
#    'assume_0_accuracy': 0.7654320987654322,
#    'assume_0_confusion': array([[  0, 186],
#           [ 57,   0]]),
#    'method': 'Host'}],
#  1030: [{'accuracy': 0.8539325842696629,
#    'confusion': array([[1369,   16],
#           [ 244,  151]]),
#    'assume_0_accuracy': 0.7780898876404494,
#    'assume_0_confusion': array([[   0, 1385],
#           [ 395,    0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6907216494845361,
#    'confusion': array([[59,  0],
#           [30,  8]]),
#    'assume_0_accuracy': 0.6082474226804124,
#    'assume_0_confusion': array([[ 0, 59],
#           [38,  0]]),
#    'method': 'Host'}],
#  1032: [{'accuracy': 0.8447142134547294,
#    'confusion': array([[1486,    8],
#           [ 299,  184]]),
#    'assume_0_accuracy': 0.7556904400606981,
#    'assume_0_confusion': array([[   0, 1494],
#           [ 483,    0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.696078431372549,
#    'confusion': array([[66,  0],
#           [31,  5]]),
#    'assume_0_accuracy': 0.6470588235294117,
#    'assume_0_confusion': array([[ 0, 66],
#           [36,  0]]),
#    'method': 'Host'}],
#  1034: [{'accuracy': 0.7337349397590361,
#    'confusion': array([[1139,   15],
#           [ 427,   79]]),
#    'assume_0_accuracy': 0.6951807228915663,
#    'assume_0_confusion': array([[   0, 1154],
#           [ 506,    0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.5925925925925926,
#    'confusion': array([[47,  1],
#           [32,  1]]),
#    'assume_0_accuracy': 0.5925925925925926,
#    'assume_0_confusion': array([[ 0, 48],
#           [33,  0]]),
#    'method': 'Host'}],
#  1114: [{'accuracy': 0.7960582690659812,
#    'confusion': array([[912,   5],
#           [233,  17]]),
#    'assume_0_accuracy': 0.7857754927163667,
#    'assume_0_confusion': array([[  0, 917],
#           [250,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.7045454545454546,
#    'confusion': array([[59,  9],
#           [17,  3]]),
#    'assume_0_accuracy': 0.7727272727272727,
#    'assume_0_confusion': array([[ 0, 68],
#           [20,  0]]),
#    'method': 'Host'}],
#  1160: [{'accuracy': 0.630891950688905,
#    'confusion': array([[837,   0],
#           [509,  33]]),
#    'assume_0_accuracy': 0.6069615663524293,
#    'assume_0_confusion': array([[  0, 837],
#           [542,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.5666666666666667,
#    'confusion': array([[59, 11],
#           [41,  9]]),
#    'assume_0_accuracy': 0.5833333333333333,
#    'assume_0_confusion': array([[ 0, 70],
#           [50,  0]]),
#    'method': 'Host'}],
#  1180: [{'accuracy': 0.6881028938906752,
#    'confusion': array([[386,  12],
#           [182,  42]]),
#    'assume_0_accuracy': 0.639871382636656,
#    'assume_0_confusion': array([[  0, 398],
#           [224,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6326530612244898,
#    'confusion': array([[26,  2],
#           [16,  5]]),
#    'assume_0_accuracy': 0.5714285714285714,
#    'assume_0_confusion': array([[ 0, 28],
#           [21,  0]]),
#    'method': 'Host'}],
#  1183: [{'accuracy': 0.7670364500792393,
#    'confusion': array([[923,   2],
#           [292,  45]]),
#    'assume_0_accuracy': 0.7329635499207607,
#    'assume_0_confusion': array([[  0, 925],
#           [337,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.7049180327868853,
#    'confusion': array([[41,  1],
#           [17,  2]]),
#    'assume_0_accuracy': 0.6885245901639344,
#    'assume_0_confusion': array([[ 0, 42],
#           [19,  0]]),
#    'method': 'Host'}],
#  1185: [{'accuracy': 0.7337142857142858,
#    'confusion': array([[615,   8],
#           [225,  27]]),
#    'assume_0_accuracy': 0.712,
#    'assume_0_confusion': array([[  0, 623],
#           [252,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6712328767123288,
#    'confusion': array([[49,  2],
#           [22,  0]]),
#    'assume_0_accuracy': 0.6986301369863014,
#    'assume_0_confusion': array([[ 0, 51],
#           [22,  0]]),
#    'method': 'Host'}],
#  1191: [{'accuracy': 0.7321428571428572,
#    'confusion': array([[626,  14],
#           [226,  30]]),
#    'assume_0_accuracy': 0.7142857142857143,
#    'assume_0_confusion': array([[  0, 640],
#           [256,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6,
#    'confusion': array([[36,  9],
#           [17,  3]]),
#    'assume_0_accuracy': 0.6923076923076923,
#    'assume_0_confusion': array([[ 0, 45],
#           [20,  0]]),
#    'method': 'Host'}],
#  1249: [{'accuracy': 0.7733118971061093,
#    'confusion': array([[479,   2],
#           [139,   2]]),
#    'assume_0_accuracy': 0.7733118971061093,
#    'assume_0_confusion': array([[  0, 481],
#           [141,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6363636363636364,
#    'confusion': array([[18,  5],
#           [ 7,  3]]),
#    'assume_0_accuracy': 0.696969696969697,
#    'assume_0_confusion': array([[ 0, 23],
#           [10,  0]]),
#    'method': 'Host'}],
#  1317: [{'accuracy': 0.9177316293929713,
#    'confusion': array([[1006,    0],
#           [ 103,  143]]),
#    'assume_0_accuracy': 0.8035143769968052,
#    'assume_0_confusion': array([[   0, 1006],
#           [ 246,    0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.7560975609756098,
#    'confusion': array([[46, 15],
#           [ 5, 16]]),
#    'assume_0_accuracy': 0.7439024390243902,
#    'assume_0_confusion': array([[ 0, 61],
#           [21,  0]]),
#    'method': 'Host'}],
#  1318: [{'accuracy': 0.6993197278911565,
#    'confusion': array([[485,   4],
#           [217,  29]]),
#    'assume_0_accuracy': 0.6653061224489796,
#    'assume_0_confusion': array([[  0, 489],
#           [246,   0]]),
#    'method': 'Clustering'}],
#  1329: [{'accuracy': 0.72910927456382,
#    'confusion': array([[725,   3],
#           [292,  69]]),
#    'assume_0_accuracy': 0.6685032139577594,
#    'assume_0_confusion': array([[  0, 728],
#           [361,   0]]),
#    'method': 'Clustering'}],
#  1338: [{'accuracy': 0.7355623100303952,
#    'confusion': array([[982,  15],
#           [420, 228]]),
#    'assume_0_accuracy': 0.6060790273556231,
#    'assume_0_confusion': array([[  0, 997],
#           [648,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.5448275862068965,
#    'confusion': array([[36, 41],
#           [25, 43]]),
#    'assume_0_accuracy': 0.5310344827586206,
#    'assume_0_confusion': array([[ 0, 77],
#           [68,  0]]),
#    'method': 'Host'}],
#  1355: [{'accuracy': 0.8449612403100775,
#    'confusion': array([[399,   2],
#           [ 78,  37]]),
#    'assume_0_accuracy': 0.7771317829457365,
#    'assume_0_confusion': array([[  0, 401],
#           [115,   0]]),
#    'method': 'Clustering'}],
#  1356: [{'accuracy': 0.6117824773413898,
#    'confusion': array([[392,   7],
#           [250,  13]]),
#    'assume_0_accuracy': 0.6027190332326284,
#    'assume_0_confusion': array([[  0, 399],
#           [263,   0]]),
#    'method': 'Clustering'}],
#  1368: [{'accuracy': 0.8845315904139434,
#    'confusion': array([[343,  10],
#           [ 43,  63]]),
#    'assume_0_accuracy': 0.7690631808278867,
#    'assume_0_confusion': array([[  0, 353],
#           [106,   0]]),
#    'method': 'Clustering'}],
#  1425: [{'accuracy': 0.870722433460076,
#    'confusion': array([[458,  16],
#           [ 52,   0]]),
#    'assume_0_accuracy': 0.9011406844106464,
#    'assume_0_confusion': array([[  0, 474],
#           [ 52,   0]]),
#    'method': 'Clustering'}],
#  1496: [{'accuracy': 0.7941368078175896,
#    'confusion': array([[1167,    5],
#           [ 311,   52]]),
#    'assume_0_accuracy': 0.7635179153094462,
#    'assume_0_confusion': array([[   0, 1172],
#           [ 363,    0]]),
#    'method': 'Clustering'}],
#  1505: [{'accuracy': 0.7558479532163742,
#    'confusion': array([[472,   3],
#           [164,  45]]),
#    'assume_0_accuracy': 0.6944444444444444,
#    'assume_0_confusion': array([[  0, 475],
#           [209,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.7205882352941176,
#    'confusion': array([[47,  1],
#           [18,  2]]),
#    'assume_0_accuracy': 0.7058823529411764,
#    'assume_0_confusion': array([[ 0, 48],
#           [20,  0]]),
#    'method': 'Host'}],
#  1534: [{'accuracy': 0.7110726643598616,
#    'confusion': array([[373,   4],
#           [163,  38]]),
#    'assume_0_accuracy': 0.6522491349480969,
#    'assume_0_confusion': array([[  0, 377],
#           [201,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6046511627906976,
#    'confusion': array([[22,  3],
#           [14,  4]]),
#    'assume_0_accuracy': 0.5813953488372092,
#    'assume_0_confusion': array([[ 0, 25],
#           [18,  0]]),
#    'method': 'Host'}],
#  1546: [{'accuracy': 0.6589147286821706,
#    'confusion': array([[158,   4],
#           [ 84,  12]]),
#    'assume_0_accuracy': 0.627906976744186,
#    'assume_0_confusion': array([[  0, 162],
#           [ 96,   0]]),
#    'method': 'Clustering'}],
#  1548: [{'accuracy': 0.8619582664526485,
#    'confusion': array([[530,   3],
#           [ 83,   7]]),
#    'assume_0_accuracy': 0.85553772070626,
#    'assume_0_confusion': array([[  0, 533],
#           [ 90,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6470588235294117,
#    'confusion': array([[20,  6],
#           [ 6,  2]]),
#    'assume_0_accuracy': 0.7647058823529411,
#    'assume_0_confusion': array([[ 0, 26],
#           [ 8,  0]]),
#    'method': 'Host'}],
#  1557: [{'accuracy': 0.7825464949928469,
#    'confusion': array([[514,   3],
#           [149,  33]]),
#    'assume_0_accuracy': 0.7396280400572246,
#    'assume_0_confusion': array([[  0, 517],
#           [182,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.7884615384615384,
#    'confusion': array([[35,  1],
#           [10,  6]]),
#    'assume_0_accuracy': 0.6923076923076923,
#    'assume_0_confusion': array([[ 0, 36],
#           [16,  0]]),
#    'method': 'Host'}],
#  1576: [{'accuracy': 0.8038674033149171,
#    'confusion': array([[556,   2],
#           [140,  26]]),
#    'assume_0_accuracy': 0.7707182320441989,
#    'assume_0_confusion': array([[  0, 558],
#           [166,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6136363636363636,
#    'confusion': array([[25,  0],
#           [17,  2]]),
#    'assume_0_accuracy': 0.5681818181818181,
#    'assume_0_confusion': array([[ 0, 25],
#           [19,  0]]),
#    'method': 'Host'}],
#  1598: [{'accuracy': 0.7539304430681277,
#    'confusion': array([[2802,    9],
#           [1024,  363]]),
#    'assume_0_accuracy': 0.6696045736064793,
#    'assume_0_confusion': array([[   0, 2811],
#           [1387,    0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.5538461538461539,
#    'confusion': array([[171,  18],
#           [127,   9]]),
#    'assume_0_accuracy': 0.5815384615384616,
#    'assume_0_confusion': array([[  0, 189],
#           [136,   0]]),
#    'method': 'Host'}],
#  1599: [{'accuracy': 0.8377581120943953,
#    'confusion': array([[550,   2],
#           [108,  18]]),
#    'assume_0_accuracy': 0.8141592920353982,
#    'assume_0_confusion': array([[  0, 552],
#           [126,   0]]),
#    'method': 'Clustering'}],
#  1601: [{'accuracy': 0.7888198757763976,
#    'confusion': array([[  0,  48],
#           [ 20, 254]]),
#    'assume_0_accuracy': 0.8509316770186336,
#    'assume_0_confusion': array([[ 48,   0],
#           [  0, 274]]),
#    'method': 'Clustering'}],
#  1646: [{'accuracy': 0.7203302373581011,
#    'confusion': array([[687,   0],
#           [271,  11]]),
#    'assume_0_accuracy': 0.7089783281733746,
#    'assume_0_confusion': array([[  0, 687],
#           [282,   0]]),
#    'method': 'Clustering'}],
#  1658: [{'accuracy': 0.7425695110258869,
#    'confusion': array([[1517,   18],
#           [ 519,   32]]),
#    'assume_0_accuracy': 0.7358581016299137,
#    'assume_0_confusion': array([[   0, 1535],
#           [ 551,    0]]),
#    'method': 'Clustering'}],
#  1665: [{'accuracy': 0.7753743760399334,
#    'confusion': array([[435,   5],
#           [130,  31]]),
#    'assume_0_accuracy': 0.7321131447587355,
#    'assume_0_confusion': array([[  0, 440],
#           [161,   0]]),
#    'method': 'Clustering'}],
#  1729: [{'accuracy': 0.8672131147540983,
#    'confusion': array([[486,   0],
#           [ 81,  43]]),
#    'assume_0_accuracy': 0.7967213114754098,
#    'assume_0_confusion': array([[  0, 486],
#           [124,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6176470588235294,
#    'confusion': array([[18,  9],
#           [ 4,  3]]),
#    'assume_0_accuracy': 0.7941176470588236,
#    'assume_0_confusion': array([[ 0, 27],
#           [ 7,  0]]),
#    'method': 'Host'}],
#  1731: [{'accuracy': 0.8048,
#    'confusion': array([[490,   3],
#           [119,  13]]),
#    'assume_0_accuracy': 0.7888,
#    'assume_0_confusion': array([[  0, 493],
#           [132,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6944444444444444,
#    'confusion': array([[25,  0],
#           [11,  0]]),
#    'assume_0_accuracy': 0.6944444444444444,
#    'assume_0_confusion': array([[ 0, 25],
#           [11,  0]]),
#    'method': 'Host'}],
#  1734: [{'accuracy': 0.6140519730510106,
#    'confusion': array([[618,   2],
#           [399,  20]]),
#    'assume_0_accuracy': 0.5967276227141483,
#    'assume_0_confusion': array([[  0, 620],
#           [419,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.5714285714285714,
#    'confusion': array([[51,  1],
#           [38,  1]]),
#    'assume_0_accuracy': 0.5714285714285714,
#    'assume_0_confusion': array([[ 0, 52],
#           [39,  0]]),
#    'method': 'Host'}],
#  1765: [{'accuracy': 0.7053469852104665,
#    'confusion': array([[588,   4],
#           [255,  32]]),
#    'assume_0_accuracy': 0.6734926052332195,
#    'assume_0_confusion': array([[  0, 592],
#           [287,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6666666666666667,
#    'confusion': array([[27,  1],
#           [13,  1]]),
#    'assume_0_accuracy': 0.6666666666666667,
#    'assume_0_confusion': array([[ 0, 28],
#           [14,  0]]),
#    'method': 'Host'}],
#  1795: [{'accuracy': 0.8067520372526193,
#    'confusion': array([[1957,    6],
#           [ 492,  122]]),
#    'assume_0_accuracy': 0.7617384555684905,
#    'assume_0_confusion': array([[   0, 1963],
#           [ 614,    0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.7142857142857143,
#    'confusion': array([[97,  0],
#           [40,  3]]),
#    'assume_0_accuracy': 0.6928571428571428,
#    'assume_0_confusion': array([[ 0, 97],
#           [43,  0]]),
#    'method': 'Host'}],
#  1858: [{'accuracy': 0.6785370548604428,
#    'confusion': array([[641,   5],
#           [329,  64]]),
#    'assume_0_accuracy': 0.6217516843118382,
#    'assume_0_confusion': array([[  0, 646],
#           [393,   0]]),
#    'method': 'Clustering'}],
#  1859: [{'accuracy': 0.7368779822767553,
#    'confusion': array([[1061,    5],
#           [ 381,   20]]),
#    'assume_0_accuracy': 0.7266530334014997,
#    'assume_0_confusion': array([[   0, 1066],
#           [ 401,    0]]),
#    'method': 'Clustering'}],
#  1873: [{'accuracy': 0.799336038362228,
#    'confusion': array([[2047,   13],
#           [ 531,  120]]),
#    'assume_0_accuracy': 0.7598672076724455,
#    'assume_0_confusion': array([[   0, 2060],
#           [ 651,    0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.7272727272727273,
#    'confusion': array([[94,  0],
#           [36,  2]]),
#    'assume_0_accuracy': 0.7121212121212122,
#    'assume_0_confusion': array([[ 0, 94],
#           [38,  0]]),
#    'method': 'Host'}],
#  1876: [{'accuracy': 0.7985611510791367,
#    'confusion': array([[439,   4],
#           [108,   5]]),
#    'assume_0_accuracy': 0.7967625899280575,
#    'assume_0_confusion': array([[  0, 443],
#           [113,   0]]),
#    'method': 'Clustering'}],
#  1881: [{'accuracy': 0.8391684901531729,
#    'confusion': array([[1455,    4],
#           [ 290,   79]]),
#    'assume_0_accuracy': 0.7981400437636761,
#    'assume_0_confusion': array([[   0, 1459],
#           [ 369,    0]]),
#    'method': 'Clustering'}],
#  1893: [{'accuracy': 0.5711422845691383,
#    'confusion': array([[222,   5],
#           [209,  63]]),
#    'assume_0_accuracy': 0.5450901803607214,
#    'assume_0_confusion': array([[227,   0],
#           [  0, 272]]),
#    'method': 'Clustering'}],
#  1909: [{'accuracy': 0.8151041666666666,
#    'confusion': array([[612,   2],
#           [140,  14]]),
#    'assume_0_accuracy': 0.7994791666666666,
#    'assume_0_confusion': array([[  0, 614],
#           [154,   0]]),
#    'method': 'Clustering'}],
#  1912: [{'accuracy': 0.8875,
#    'confusion': array([[701,  13],
#           [ 77,   9]]),
#    'assume_0_accuracy': 0.8925,
#    'assume_0_confusion': array([[  0, 714],
#           [ 86,   0]]),
#    'method': 'Clustering'}],
#  1941: [{'accuracy': 0.8179775280898877,
#    'confusion': array([[348,   5],
#           [ 76,  16]]),
#    'assume_0_accuracy': 0.7932584269662921,
#    'assume_0_confusion': array([[  0, 353],
#           [ 92,   0]]),
#    'method': 'Clustering'}],
#  1942: [{'accuracy': 0.7908496732026143,
#    'confusion': array([[567,   9],
#           [151,  38]]),
#    'assume_0_accuracy': 0.7529411764705882,
#    'assume_0_confusion': array([[  0, 576],
#           [189,   0]]),
#    'method': 'Clustering'}],
#  1967: [{'accuracy': 0.7719033232628398,
#    'confusion': array([[490,   3],
#           [148,  21]]),
#    'assume_0_accuracy': 0.744712990936556,
#    'assume_0_confusion': array([[  0, 493],
#           [169,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6,
#    'confusion': array([[19, 11],
#           [ 9, 11]]),
#    'assume_0_accuracy': 0.6,
#    'assume_0_confusion': array([[ 0, 30],
#           [20,  0]]),
#    'method': 'Host'}],
#  1973: [{'accuracy': 0.7536023054755043,
#    'confusion': array([[504,   6],
#           [165,  19]]),
#    'assume_0_accuracy': 0.7348703170028819,
#    'assume_0_confusion': array([[  0, 510],
#           [184,   0]]),
#    'method': 'Clustering'}],
#  1997: [{'accuracy': 0.792063492063492,
#    'confusion': array([[470,  14],
#           [117,  29]]),
#    'assume_0_accuracy': 0.7682539682539682,
#    'assume_0_confusion': array([[  0, 484],
#           [146,   0]]),
#    'method': 'Clustering'}],
#  2007: [{'accuracy': 0.8520801232665639,
#    'confusion': array([[540,   3],
#           [ 93,  13]]),
#    'assume_0_accuracy': 0.8366718027734977,
#    'assume_0_confusion': array([[  0, 543],
#           [106,   0]]),
#    'method': 'Clustering'}],
#  2011: [{'accuracy': 0.7859560067681894,
#    'confusion': array([[861,   4],
#           [249,  68]]),
#    'assume_0_accuracy': 0.7318104906937395,
#    'assume_0_confusion': array([[  0, 865],
#           [317,   0]]),
#    'method': 'Clustering'}],
#  2021: [{'accuracy': 0.864297253634895,
#    'confusion': array([[505,  17],
#           [ 67,  30]]),
#    'assume_0_accuracy': 0.8432956381260097,
#    'assume_0_confusion': array([[  0, 522],
#           [ 97,   0]]),
#    'method': 'Clustering'}],
#  2095: [{'accuracy': 0.7616361071932299,
#    'confusion': array([[508,   7],
#           [162,  32]]),
#    'assume_0_accuracy': 0.7263751763046544,
#    'assume_0_confusion': array([[  0, 515],
#           [194,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6428571428571428,
#    'confusion': array([[22,  4],
#           [11,  5]]),
#    'assume_0_accuracy': 0.6190476190476191,
#    'assume_0_confusion': array([[ 0, 26],
#           [16,  0]]),
#    'method': 'Host'}],
#  2107: [{'accuracy': 0.728169014084507,
#    'confusion': array([[479,   4],
#           [189,  38]]),
#    'assume_0_accuracy': 0.680281690140845,
#    'assume_0_confusion': array([[  0, 483],
#           [227,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6229508196721312,
#    'confusion': array([[36,  3],
#           [20,  2]]),
#    'assume_0_accuracy': 0.639344262295082,
#    'assume_0_confusion': array([[ 0, 39],
#           [22,  0]]),
#    'method': 'Host'}],
#  2109: [{'accuracy': 0.6835664335664335,
#    'confusion': array([[767,   3],
#           [359,  15]]),
#    'assume_0_accuracy': 0.6730769230769231,
#    'assume_0_confusion': array([[  0, 770],
#           [374,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.7424242424242424,
#    'confusion': array([[48,  1],
#           [16,  1]]),
#    'assume_0_accuracy': 0.7424242424242424,
#    'assume_0_confusion': array([[ 0, 49],
#           [17,  0]]),
#    'method': 'Host'}],
#  2135: [{'accuracy': 0.8700696055684455,
#    'confusion': array([[352,   3],
#           [ 53,  23]]),
#    'assume_0_accuracy': 0.8236658932714618,
#    'assume_0_confusion': array([[  0, 355],
#           [ 76,   0]]),
#    'method': 'Clustering'}],
#  2136: [{'accuracy': 0.831858407079646,
#    'confusion': array([[255,   6],
#           [ 51,  27]]),
#    'assume_0_accuracy': 0.7699115044247787,
#    'assume_0_confusion': array([[  0, 261],
#           [ 78,   0]]),
#    'method': 'Clustering'}],
#  2145: [{'accuracy': 0.784394250513347,
#    'confusion': array([[361,   6],
#           [ 99,  21]]),
#    'assume_0_accuracy': 0.7535934291581109,
#    'assume_0_confusion': array([[  0, 367],
#           [120,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6842105263157895,
#    'confusion': array([[25,  1],
#           [11,  1]]),
#    'assume_0_accuracy': 0.6842105263157895,
#    'assume_0_confusion': array([[ 0, 26],
#           [12,  0]]),
#    'method': 'Host'}],
#  2160: [{'accuracy': 0.7803410230692076,
#    'confusion': array([[740,   4],
#           [215,  38]]),
#    'assume_0_accuracy': 0.7462387161484454,
#    'assume_0_confusion': array([[  0, 744],
#           [253,   0]]),
#    'method': 'Clustering'}],
#  2180: [{'accuracy': 0.8725761772853186,
#    'confusion': array([[595,   3],
#           [ 89,  35]]),
#    'assume_0_accuracy': 0.8282548476454293,
#    'assume_0_confusion': array([[  0, 598],
#           [124,   0]]),
#    'method': 'Clustering'}],
#  2224: [{'accuracy': 0.7858176555716353,
#    'confusion': array([[506,   5],
#           [143,  37]]),
#    'assume_0_accuracy': 0.7395079594790159,
#    'assume_0_confusion': array([[  0, 511],
#           [180,   0]]),
#    'method': 'Clustering'}],
#  2232: [{'accuracy': 0.7923497267759563,
#    'confusion': array([[529,   2],
#           [150,  51]]),
#    'assume_0_accuracy': 0.7254098360655737,
#    'assume_0_confusion': array([[  0, 531],
#           [201,   0]]),
#    'method': 'Clustering'}],
#  2240: [{'accuracy': 0.8622448979591837,
#    'confusion': array([[478,   2],
#           [ 79,  29]]),
#    'assume_0_accuracy': 0.8163265306122449,
#    'assume_0_confusion': array([[  0, 480],
#           [108,   0]]),
#    'method': 'Clustering'}],
#  2243: [{'accuracy': 0.8669410150891632,
#    'confusion': array([[567,   2],
#           [ 95,  65]]),
#    'assume_0_accuracy': 0.7805212620027435,
#    'assume_0_confusion': array([[  0, 569],
#           [160,   0]]),
#    'method': 'Clustering'}],
#  2247: [{'accuracy': 0.7869362363919129,
#    'confusion': array([[499,   3],
#           [134,   7]]),
#    'assume_0_accuracy': 0.7807153965785381,
#    'assume_0_confusion': array([[  0, 502],
#           [141,   0]]),
#    'method': 'Clustering'}],
#  2252: [{'accuracy': 0.7800891530460624,
#    'confusion': array([[462,   2],
#           [146,  63]]),
#    'assume_0_accuracy': 0.6894502228826151,
#    'assume_0_confusion': array([[  0, 464],
#           [209,   0]]),
#    'method': 'Clustering'}],
#  2260: [{'accuracy': 0.6354883081155434,
#    'confusion': array([[426,   7],
#           [258,  36]]),
#    'assume_0_accuracy': 0.5955983493810179,
#    'assume_0_confusion': array([[  0, 433],
#           [294,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6097560975609756,
#    'confusion': array([[23,  0],
#           [16,  2]]),
#    'assume_0_accuracy': 0.5609756097560976,
#    'assume_0_confusion': array([[ 0, 23],
#           [18,  0]]),
#    'method': 'Host'}],
#  2268: [{'accuracy': 0.611214953271028,
#    'confusion': array([[632,   1],
#           [415,  22]]),
#    'assume_0_accuracy': 0.591588785046729,
#    'assume_0_confusion': array([[  0, 633],
#           [437,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.5211267605633803,
#    'confusion': array([[34,  2],
#           [32,  3]]),
#    'assume_0_accuracy': 0.5070422535211268,
#    'assume_0_confusion': array([[ 0, 36],
#           [35,  0]]),
#    'method': 'Host'}],
#  2272: [{'accuracy': 0.7329942784488239,
#    'confusion': array([[1083,    5],
#           [ 415,   70]]),
#    'assume_0_accuracy': 0.6916719643992371,
#    'assume_0_confusion': array([[   0, 1088],
#           [ 485,    0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.5581395348837209,
#    'confusion': array([[46,  1],
#           [37,  2]]),
#    'assume_0_accuracy': 0.5465116279069768,
#    'assume_0_confusion': array([[ 0, 47],
#           [39,  0]]),
#    'method': 'Host'}],
#  2355: [{'accuracy': 0.8169014084507042,
#    'confusion': array([[540,   4],
#           [139,  98]]),
#    'assume_0_accuracy': 0.6965428937259923,
#    'assume_0_confusion': array([[  0, 544],
#           [237,   0]]),
#    'method': 'Clustering'}],
#  2375: [{'accuracy': 0.7694753577106519,
#    'confusion': array([[445,   3],
#           [142,  39]]),
#    'assume_0_accuracy': 0.712241653418124,
#    'assume_0_confusion': array([[  0, 448],
#           [181,   0]]),
#    'method': 'Clustering'}],
#  2393: [{'accuracy': 0.821247892074199,
#    'confusion': array([[441,  17],
#           [ 89,  46]]),
#    'assume_0_accuracy': 0.7723440134907251,
#    'assume_0_confusion': array([[  0, 458],
#           [135,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6944444444444444,
#    'confusion': array([[24,  1],
#           [10,  1]]),
#    'assume_0_accuracy': 0.6944444444444444,
#    'assume_0_confusion': array([[ 0, 25],
#           [11,  0]]),
#    'method': 'Host'}],
#  2399: [{'accuracy': 0.6775244299674268,
#    'confusion': array([[409,   4],
#           [194,   7]]),
#    'assume_0_accuracy': 0.6726384364820848,
#    'assume_0_confusion': array([[  0, 413],
#           [201,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.7391304347826086,
#    'confusion': array([[33,  2],
#           [10,  1]]),
#    'assume_0_accuracy': 0.7608695652173914,
#    'assume_0_confusion': array([[ 0, 35],
#           [11,  0]]),
#    'method': 'Host'}],
#  2421: [{'accuracy': 0.7042925278219396,
#    'confusion': array([[422,   4],
#           [182,  21]]),
#    'assume_0_accuracy': 0.6772655007949125,
#    'assume_0_confusion': array([[  0, 426],
#           [203,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.5111111111111111,
#    'confusion': array([[13,  8],
#           [14, 10]]),
#    'assume_0_accuracy': 0.5333333333333333,
#    'assume_0_confusion': array([[21,  0],
#           [ 0, 24]]),
#    'method': 'Host'}],
#  2479: [{'accuracy': 0.7765273311897106,
#    'confusion': array([[450,   4],
#           [135,  33]]),
#    'assume_0_accuracy': 0.729903536977492,
#    'assume_0_confusion': array([[  0, 454],
#           [168,   0]]),
#    'method': 'Clustering'}],
#  2489: [{'accuracy': 0.8567530695770805,
#    'confusion': array([[597,   9],
#           [ 96,  31]]),
#    'assume_0_accuracy': 0.8267394270122783,
#    'assume_0_confusion': array([[  0, 606],
#           [127,   0]]),
#    'method': 'Clustering'}],
#  2493: [{'accuracy': 0.9242957746478874,
#    'confusion': array([[513,   3],
#           [ 40,  12]]),
#    'assume_0_accuracy': 0.9084507042253521,
#    'assume_0_confusion': array([[  0, 516],
#           [ 52,   0]]),
#    'method': 'Clustering'}],
#  2587: [{'accuracy': 0.6894164193867458,
#    'confusion': array([[669,  15],
#           [299,  28]]),
#    'assume_0_accuracy': 0.6765578635014837,
#    'assume_0_confusion': array([[  0, 684],
#           [327,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.6,
#    'confusion': array([[41,  4],
#           [24,  1]]),
#    'assume_0_accuracy': 0.6428571428571428,
#    'assume_0_confusion': array([[ 0, 45],
#           [25,  0]]),
#    'method': 'Host'}],
#  2589: [{'accuracy': 0.7639553429027113,
#    'confusion': array([[438,   5],
#           [143,  41]]),
#    'assume_0_accuracy': 0.7065390749601276,
#    'assume_0_confusion': array([[  0, 443],
#           [184,   0]]),
#    'method': 'Clustering'}],
#  2596: [{'accuracy': 0.7555938037865748,
#    'confusion': array([[416,   4],
#           [138,  23]]),
#    'assume_0_accuracy': 0.7228915662650602,
#    'assume_0_confusion': array([[  0, 420],
#           [161,   0]]),
#    'method': 'Clustering'}],
#  2597: [{'accuracy': 0.7019748653500898,
#    'confusion': array([[303,   2],
#           [164,  88]]),
#    'assume_0_accuracy': 0.5475763016157988,
#    'assume_0_confusion': array([[  0, 305],
#           [252,   0]]),
#    'method': 'Clustering'}],
#  2607: [{'accuracy': 0.8107734806629834,
#    'confusion': array([[565,   4],
#           [133,  22]]),
#    'assume_0_accuracy': 0.7859116022099447,
#    'assume_0_confusion': array([[  0, 569],
#           [155,   0]]),
#    'method': 'Clustering'}],
#  2615: [{'accuracy': 0.6927502876869965,
#    'confusion': array([[581,   4],
#           [263,  21]]),
#    'assume_0_accuracy': 0.6731875719217492,
#    'assume_0_confusion': array([[  0, 585],
#           [284,   0]]),
#    'method': 'Clustering'}],
#  2617: [{'accuracy': 0.7615571776155717,
#    'confusion': array([[ 14,  81],
#           [ 17, 299]]),
#    'assume_0_accuracy': 0.7688564476885644,
#    'assume_0_confusion': array([[ 95,   0],
#           [  0, 316]]),
#    'method': 'Clustering'}],
#  2627: [{'accuracy': 0.7514450867052023,
#    'confusion': array([[486,   4],
#           [168,  34]]),
#    'assume_0_accuracy': 0.708092485549133,
#    'assume_0_confusion': array([[  0, 490],
#           [202,   0]]),
#    'method': 'Clustering'}],
#  2636: [{'accuracy': 0.8034934497816594,
#    'confusion': array([[504,   3],
#           [132,  48]]),
#    'assume_0_accuracy': 0.7379912663755459,
#    'assume_0_confusion': array([[  0, 507],
#           [180,   0]]),
#    'method': 'Clustering'}],
#  2637: [{'accuracy': 0.9244094488188976,
#    'confusion': array([[554,   5],
#           [ 43,  33]]),
#    'assume_0_accuracy': 0.8803149606299212,
#    'assume_0_confusion': array([[  0, 559],
#           [ 76,   0]]),
#    'method': 'Clustering'}],
#  2656: [{'accuracy': 0.7477990678404971,
#    'confusion': array([[1364,   16],
#           [ 471,   80]]),
#    'assume_0_accuracy': 0.7146556188503366,
#    'assume_0_confusion': array([[   0, 1380],
#           [ 551,    0]]),
#    'method': 'Clustering'}],
#  2664: [{'accuracy': 0.6587771203155819,
#    'confusion': array([[302,   3],
#           [170,  32]]),
#    'assume_0_accuracy': 0.6015779092702169,
#    'assume_0_confusion': array([[  0, 305],
#           [202,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.5128205128205128,
#    'confusion': array([[ 1, 18],
#           [ 1, 19]]),
#    'assume_0_accuracy': 0.5128205128205128,
#    'assume_0_confusion': array([[19,  0],
#           [ 0, 20]]),
#    'method': 'Host'}],
#  2748: [{'accuracy': 0.7901694915254237,
#    'confusion': array([[2165,    8],
#           [ 611,  166]]),
#    'assume_0_accuracy': 0.7366101694915255,
#    'assume_0_confusion': array([[   0, 2173],
#           [ 777,    0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.5838509316770186,
#    'confusion': array([[91, 15],
#           [52,  3]]),
#    'assume_0_accuracy': 0.6583850931677019,
#    'assume_0_confusion': array([[  0, 106],
#           [ 55,   0]]),
#    'method': 'Host'}],
#  2778: [{'accuracy': 0.6014234875444839,
#    'confusion': array([[ 42, 166],
#           [ 58, 296]]),
#    'assume_0_accuracy': 0.6298932384341637,
#    'assume_0_confusion': array([[208,   0],
#           [  0, 354]]),
#    'method': 'Clustering'}],
#  2800: [{'accuracy': 0.697986577181208,
#    'confusion': array([[377,   5],
#           [175,  39]]),
#    'assume_0_accuracy': 0.6409395973154363,
#    'assume_0_confusion': array([[  0, 382],
#           [214,   0]]),
#    'method': 'Clustering'}],
#  2807: [{'accuracy': 0.826151560178306,
#    'confusion': array([[477,  12],
#           [105,  79]]),
#    'assume_0_accuracy': 0.7265973254086182,
#    'assume_0_confusion': array([[  0, 489],
#           [184,   0]]),
#    'method': 'Clustering'}],
#  2824: [{'accuracy': 0.8046153846153846,
#    'confusion': array([[482,   6],
#           [121,  41]]),
#    'assume_0_accuracy': 0.7507692307692307,
#    'assume_0_confusion': array([[  0, 488],
#           [162,   0]]),
#    'method': 'Clustering'}],
#  2831: [{'accuracy': 0.8185567010309278,
#    'confusion': array([[776,   2],
#           [174,  18]]),
#    'assume_0_accuracy': 0.8020618556701031,
#    'assume_0_confusion': array([[  0, 778],
#           [192,   0]]),
#    'method': 'Clustering'}],
#  2835: [{'accuracy': 0.8692220969560316,
#    'confusion': array([[757,   3],
#           [113,  14]]),
#    'assume_0_accuracy': 0.8568207440811725,
#    'assume_0_confusion': array([[  0, 760],
#           [127,   0]]),
#    'method': 'Clustering'}],
#  2851: [{'accuracy': 0.949685534591195,
#    'confusion': array([[438,   7],
#           [ 17,  15]]),
#    'assume_0_accuracy': 0.9329140461215932,
#    'assume_0_confusion': array([[  0, 445],
#           [ 32,   0]]),
#    'method': 'Clustering'}],
#  2869: [{'accuracy': 0.8556827473426002,
#    'confusion': array([[1953,    1],
#           [ 352,  140]]),
#    'assume_0_accuracy': 0.7988552739165985,
#    'assume_0_confusion': array([[   0, 1954],
#           [ 492,    0]]),
#    'method': 'Clustering'}],
#  2874: [{'accuracy': 0.7287735849056604,
#    'confusion': array([[309, 100],
#           [ 15,   0]]),
#    'assume_0_accuracy': 0.964622641509434,
#    'assume_0_confusion': array([[  0, 409],
#           [ 15,   0]]),
#    'method': 'Clustering'}],
#  2899: [{'accuracy': 0.6860242501595406,
#    'confusion': array([[1050,    2],
#           [ 490,   25]]),
#    'assume_0_accuracy': 0.6713465220165922,
#    'assume_0_confusion': array([[   0, 1052],
#           [ 515,    0]]),
#    'method': 'Clustering'}],
#  2904: [{'accuracy': 0.5686032138442522,
#    'confusion': array([[417,   1],
#           [348,  43]]),
#    'assume_0_accuracy': 0.5166872682323856,
#    'assume_0_confusion': array([[  0, 418],
#           [391,   0]]),
#    'method': 'Clustering'}],
#  2923: [{'accuracy': 0.7321100917431193,
#    'confusion': array([[345,   6],
#           [140,  54]]),
#    'assume_0_accuracy': 0.6440366972477064,
#    'assume_0_confusion': array([[  0, 351],
#           [194,   0]]),
#    'method': 'Clustering'}],
#  2934: [{'accuracy': 0.7086834733893557,
#    'confusion': array([[493,   2],
#           [206,  13]]),
#    'assume_0_accuracy': 0.6932773109243697,
#    'assume_0_confusion': array([[  0, 495],
#           [219,   0]]),
#    'method': 'Clustering'}],
#  2948: [{'accuracy': 0.7644151565074135,
#    'confusion': array([[444,   3],
#           [140,  20]]),
#    'assume_0_accuracy': 0.7364085667215816,
#    'assume_0_confusion': array([[  0, 447],
#           [160,   0]]),
#    'method': 'Clustering'}],
#  2963: [{'accuracy': 0.6615252784918595,
# ...
#    'assume_0_confusion': array([[  0, 466],
#           [162,   0]]),
#    'method': 'Clustering'}],
#  52065: [{'accuracy': 0.655980271270037,
#    'confusion': array([[478,   3],
#           [276,  54]]),
#    'assume_0_accuracy': 0.593094944512947,
#    'assume_0_confusion': array([[  0, 481],
#           [330,   0]]),
#    'method': 'Clustering'}],
#  52153: [{'accuracy': 0.7524752475247525,
#    'confusion': array([[663,   2],
#           [223,  21]]),
#    'assume_0_accuracy': 0.7315731573157316,
#    'assume_0_confusion': array([[  0, 665],
#           [244,   0]]),
#    'method': 'Clustering'}],
#  52171: [{'accuracy': 0.7737881508078994,
#    'confusion': array([[396,  16],
#           [110,  35]]),
#    'assume_0_accuracy': 0.7396768402154399,
#    'assume_0_confusion': array([[  0, 412],
#           [145,   0]]),
#    'method': 'Clustering'}],
#  52184: [{'accuracy': 0.8345642540620384,
#    'confusion': array([[2144,   11],
#           [ 437,  116]]),
#    'assume_0_accuracy': 0.7957902511078286,
#    'assume_0_confusion': array([[   0, 2155],
#           [ 553,    0]]),
#    'method': 'Clustering'}],
#  52204: [{'accuracy': 0.6809411764705882,
#    'confusion': array([[1408,    6],
#           [ 672,   39]]),
#    'assume_0_accuracy': 0.6654117647058824,
#    'assume_0_confusion': array([[   0, 1414],
#           [ 711,    0]]),
#    'method': 'Clustering'}],
#  52225: [{'accuracy': 0.7116402116402116,
#    'confusion': array([[694,   5],
#           [322, 113]]),
#    'assume_0_accuracy': 0.6164021164021164,
#    'assume_0_confusion': array([[  0, 699],
#           [435,   0]]),
#    'method': 'Clustering'}],
#  52226: [{'accuracy': 0.9658444022770398,
#    'confusion': array([[475,   0],
#           [ 18,  34]]),
#    'assume_0_accuracy': 0.9013282732447818,
#    'assume_0_confusion': array([[  0, 475],
#           [ 52,   0]]),
#    'method': 'Clustering'}],
#  52235: [{'accuracy': 0.9595505617977528,
#    'confusion': array([[408,   0],
#           [ 18,  19]]),
#    'assume_0_accuracy': 0.9168539325842696,
#    'assume_0_confusion': array([[  0, 408],
#           [ 37,   0]]),
#    'method': 'Clustering'}],
#  52299: [{'accuracy': 0.8156748911465892,
#    'confusion': array([[1554,   12],
#           [ 369,  132]]),
#    'assume_0_accuracy': 0.7576197387518142,
#    'assume_0_confusion': array([[   0, 1566],
#           [ 501,    0]]),
#    'method': 'Clustering'}],
#  52313: [{'accuracy': 0.8371848739495799,
#    'confusion': array([[689,   3],
#           [152, 108]]),
#    'assume_0_accuracy': 0.7268907563025211,
#    'assume_0_confusion': array([[  0, 692],
#           [260,   0]]),
#    'method': 'Clustering'}],
#  52339: [{'accuracy': 0.7779456193353474,
#    'confusion': array([[506,  18],
#           [129,   9]]),
#    'assume_0_accuracy': 0.7915407854984894,
#    'assume_0_confusion': array([[  0, 524],
#           [138,   0]]),
#    'method': 'Clustering'}],
#  52360: [{'accuracy': 0.7397868561278863,
#    'confusion': array([[775,   1],
#           [292,  58]]),
#    'assume_0_accuracy': 0.6891651865008881,
#    'assume_0_confusion': array([[  0, 776],
#           [350,   0]]),
#    'method': 'Clustering'}],
#  52362: [{'accuracy': 0.713375796178344,
#    'confusion': array([[66,  0],
#           [45, 46]]),
#    'assume_0_accuracy': 0.5796178343949044,
#    'assume_0_confusion': array([[66,  0],
#           [ 0, 91]]),
#    'method': 'Clustering'}],
#  52389: [{'accuracy': 0.8061224489795918,
#    'confusion': array([[455,  12],
#           [102,  19]]),
#    'assume_0_accuracy': 0.7942176870748299,
#    'assume_0_confusion': array([[  0, 467],
#           [121,   0]]),
#    'method': 'Clustering'}],
#  52421: [{'accuracy': 0.5787292817679558,
#    'confusion': array([[387,   5],
#           [300,  32]]),
#    'assume_0_accuracy': 0.5414364640883977,
#    'assume_0_confusion': array([[  0, 392],
#           [332,   0]]),
#    'method': 'Clustering'}],
#  52463: [{'accuracy': 0.9165329052969502,
#    'confusion': array([[560,   0],
#           [ 52,  11]]),
#    'assume_0_accuracy': 0.898876404494382,
#    'assume_0_confusion': array([[  0, 560],
#           [ 63,   0]]),
#    'method': 'Clustering'}],
#  52465: [{'accuracy': 0.77705112960761,
#    'confusion': array([[1209,    6],
#           [ 369,   98]]),
#    'assume_0_accuracy': 0.7223543400713437,
#    'assume_0_confusion': array([[   0, 1215],
#           [ 467,    0]]),
#    'method': 'Clustering'}],
#  52485: [{'accuracy': 0.650990099009901,
#    'confusion': array([[488,   2],
#           [280,  38]]),
#    'assume_0_accuracy': 0.6064356435643564,
#    'assume_0_confusion': array([[  0, 490],
#           [318,   0]]),
#    'method': 'Clustering'}],
#  52489: [{'accuracy': 0.5570776255707763,
#    'confusion': array([[244,   9],
#           [185,   0]]),
#    'assume_0_accuracy': 0.5776255707762556,
#    'assume_0_confusion': array([[  0, 253],
#           [185,   0]]),
#    'method': 'Clustering'}],
#  52527: [{'accuracy': 0.831858407079646,
#    'confusion': array([[804,   3],
#           [168,  42]]),
#    'assume_0_accuracy': 0.7935103244837758,
#    'assume_0_confusion': array([[  0, 807],
#           [210,   0]]),
#    'method': 'Clustering'}],
#  52541: [{'accuracy': 0.7763440860215054,
#    'confusion': array([[343,   2],
#           [102,  18]]),
#    'assume_0_accuracy': 0.7419354838709677,
#    'assume_0_confusion': array([[  0, 345],
#           [120,   0]]),
#    'method': 'Clustering'}],
#  52603: [{'accuracy': 0.5485307212822796,
#    'confusion': array([[  4, 456],
#           [ 51, 612]]),
#    'assume_0_accuracy': 0.5903829029385574,
#    'assume_0_confusion': array([[460,   0],
#           [  0, 663]]),
#    'method': 'Clustering'}],
#  52614: [{'accuracy': 0.9786856127886323,
#    'confusion': array([[522,   0],
#           [ 12,  29]]),
#    'assume_0_accuracy': 0.9271758436944938,
#    'assume_0_confusion': array([[  0, 522],
#           [ 41,   0]]),
#    'method': 'Clustering'}],
#  52634: [{'accuracy': 0.8221302998965874,
#    'confusion': array([[744,   2],
#           [170,  51]]),
#    'assume_0_accuracy': 0.7714581178903827,
#    'assume_0_confusion': array([[  0, 746],
#           [221,   0]]),
#    'method': 'Clustering'}],
#  52644: [{'accuracy': 0.7613259668508288,
#    'confusion': array([[651,   4],
#           [212,  38]]),
#    'assume_0_accuracy': 0.7237569060773481,
#    'assume_0_confusion': array([[  0, 655],
#           [250,   0]]),
#    'method': 'Clustering'}],
#  52656: [{'accuracy': 0.618705035971223,
#    'confusion': array([[562,   5],
#           [366,  40]]),
#    'assume_0_accuracy': 0.5827338129496402,
#    'assume_0_confusion': array([[  0, 567],
#           [406,   0]]),
#    'method': 'Clustering'}],
#  52697: [{'accuracy': 0.6536231884057971,
#    'confusion': array([[  2, 194],
#           [ 45, 449]]),
#    'assume_0_accuracy': 0.7159420289855073,
#    'assume_0_confusion': array([[196,   0],
#           [  0, 494]]),
#    'method': 'Clustering'}],
#  52803: [{'accuracy': 0.6879535558780842,
#    'confusion': array([[430,   7],
#           [208,  44]]),
#    'assume_0_accuracy': 0.6342525399129173,
#    'assume_0_confusion': array([[  0, 437],
#           [252,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.5227272727272727,
#    'confusion': array([[20,  3],
#           [18,  3]]),
#    'assume_0_accuracy': 0.5227272727272727,
#    'assume_0_confusion': array([[ 0, 23],
#           [21,  0]]),
#    'method': 'Host'}],
#  52818: [{'accuracy': 0.7551410808225729,
#    'confusion': array([[1379,    5],
#           [ 507,  200]]),
#    'assume_0_accuracy': 0.6618842659014825,
#    'assume_0_confusion': array([[   0, 1384],
#           [ 707,    0]]),
#    'method': 'Clustering'}],
#  52820: [{'accuracy': 0.944,
#    'confusion': array([[566,  24],
#           [ 11,  24]]),
#    'assume_0_accuracy': 0.944,
#    'assume_0_confusion': array([[  0, 590],
#           [ 35,   0]]),
#    'method': 'Clustering'}],
#  52881: [{'accuracy': 0.8640625,
#    'confusion': array([[526,   5],
#           [ 82,  27]]),
#    'assume_0_accuracy': 0.8296875,
#    'assume_0_confusion': array([[  0, 531],
#           [109,   0]]),
#    'method': 'Clustering'}],
#  52891: [{'accuracy': 0.7642642642642643,
#    'confusion': array([[436,   3],
#           [154,  73]]),
#    'assume_0_accuracy': 0.6591591591591592,
#    'assume_0_confusion': array([[  0, 439],
#           [227,   0]]),
#    'method': 'Clustering'}],
#  52922: [{'accuracy': 0.9163636363636364,
#    'confusion': array([[490,  27],
#           [ 19,  14]]),
#    'assume_0_accuracy': 0.94,
#    'assume_0_confusion': array([[  0, 517],
#           [ 33,   0]]),
#    'method': 'Clustering'}],
#  52975: [{'accuracy': 0.8409475465313029,
#    'confusion': array([[464,   8],
#           [ 86,  33]]),
#    'assume_0_accuracy': 0.7986463620981388,
#    'assume_0_confusion': array([[  0, 472],
#           [119,   0]]),
#    'method': 'Clustering'}],
#  53035: [{'accuracy': 0.8057663125948407,
#    'confusion': array([[503,   3],
#           [125,  28]]),
#    'assume_0_accuracy': 0.7678300455235205,
#    'assume_0_confusion': array([[  0, 506],
#           [153,   0]]),
#    'method': 'Clustering'}],
#  53046: [{'accuracy': 0.8982706002034588,
#    'confusion': array([[814,   0],
#           [100,  69]]),
#    'assume_0_accuracy': 0.8280773143438453,
#    'assume_0_confusion': array([[  0, 814],
#           [169,   0]]),
#    'method': 'Clustering'}],
#  53062: [{'accuracy': 0.8952380952380953,
#    'confusion': array([[  0,  57],
#           [  9, 564]]),
#    'assume_0_accuracy': 0.9095238095238095,
#    'assume_0_confusion': array([[ 57,   0],
#           [  0, 573]]),
#    'method': 'Clustering'}],
#  53065: [{'accuracy': 0.6047087980173482,
#    'confusion': array([[485,   2],
#           [317,   3]]),
#    'assume_0_accuracy': 0.6034696406443618,
#    'assume_0_confusion': array([[  0, 487],
#           [320,   0]]),
#    'method': 'Clustering'}],
#  53128: [{'accuracy': 0.7073170731707317,
#    'confusion': array([[507,   0],
#           [216,  15]]),
#    'assume_0_accuracy': 0.6869918699186992,
#    'assume_0_confusion': array([[  0, 507],
#           [231,   0]]),
#    'method': 'Clustering'}],
#  53132: [{'accuracy': 0.7057435090479938,
#    'confusion': array([[847,   1],
#           [373,  50]]),
#    'assume_0_accuracy': 0.6671911880409127,
#    'assume_0_confusion': array([[  0, 848],
#           [423,   0]]),
#    'method': 'Clustering'}],
#  53140: [{'accuracy': 0.8090909090909091,
#    'confusion': array([[749,   4],
#           [185,  52]]),
#    'assume_0_accuracy': 0.7606060606060606,
#    'assume_0_confusion': array([[  0, 753],
#           [237,   0]]),
#    'method': 'Clustering'}],
#  53155: [{'accuracy': 0.778021978021978,
#    'confusion': array([[317,   4],
#           [ 97,  37]]),
#    'assume_0_accuracy': 0.7054945054945054,
#    'assume_0_confusion': array([[  0, 321],
#           [134,   0]]),
#    'method': 'Clustering'}],
#  53181: [{'accuracy': 0.7784911717495987,
#    'confusion': array([[477,   2],
#           [136,   8]]),
#    'assume_0_accuracy': 0.768860353130016,
#    'assume_0_confusion': array([[  0, 479],
#           [144,   0]]),
#    'method': 'Clustering'},
#   {'accuracy': 0.75,
#    'confusion': array([[29,  1],
#           [ 9,  1]]),
#    'assume_0_accuracy': 0.75,
#    'assume_0_confusion': array([[ 0, 30],
#           [10,  0]]),
#    'method': 'Host'}],
#  53182: [{'accuracy': 0.6373937677053825,
#    'confusion': array([[438,   2],
#           [254,  12]]),
#    'assume_0_accuracy': 0.623229461756374,
#    'assume_0_confusion': array([[  0, 440],
#           [266,   0]]),
#    'method': 'Clustering'}],
#  53305: [{'accuracy': 0.802130898021309,
#    'confusion': array([[516,   5],
#           [125,  11]]),
#    'assume_0_accuracy': 0.7929984779299848,
#    'assume_0_confusion': array([[  0, 521],
#           [136,   0]]),
#    'method': 'Clustering'}],
#  53333: [{'accuracy': 0.7076023391812866,
#    'confusion': array([[695,   2],
#           [298,  31]]),
#    'assume_0_accuracy': 0.6793372319688109,
#    'assume_0_confusion': array([[  0, 697],
#           [329,   0]]),
#    'method': 'Clustering'}],
#  53338: [{'accuracy': 0.7375886524822695,
#    'confusion': array([[401,   1],
#           [147,  15]]),
#    'assume_0_accuracy': 0.7127659574468085,
#    'assume_0_confusion': array([[  0, 402],
#           [162,   0]]),
#    'method': 'Clustering'}],
#  53352: [{'accuracy': 0.8581081081081081,
#    'confusion': array([[920,  25],
#           [143,  96]]),
#    'assume_0_accuracy': 0.7981418918918919,
#    'assume_0_confusion': array([[  0, 945],
#           [239,   0]]),
#    'method': 'Clustering'}],
#  53458: [{'accuracy': 0.8133333333333334,
#    'confusion': array([[515,   8],
#           [118,  34]]),
#    'assume_0_accuracy': 0.7748148148148148,
#    'assume_0_confusion': array([[  0, 523],
#           [152,   0]]),
#    'method': 'Clustering'}],
#  53463: [{'accuracy': 0.8110716099542915,
#    'confusion': array([[1530,   13],
#           [ 359,   67]]),
#    'assume_0_accuracy': 0.7836465210766886,
#    'assume_0_confusion': array([[   0, 1543],
#           [ 426,    0]]),
#    'method': 'Clustering'}],
#  53488: [{'accuracy': 0.644640234948605,
#    'confusion': array([[1179,    1],
#           [ 725,  138]]),
#    'assume_0_accuracy': 0.5775819872736172,
#    'assume_0_confusion': array([[   0, 1180],
#           [ 863,    0]]),
#    'method': 'Clustering'}],
#  53553: [{'accuracy': 0.762784966112138,
#    'confusion': array([[1147,    3],
#           [ 382,   91]]),
#    'assume_0_accuracy': 0.7085643869377696,
#    'assume_0_confusion': array([[   0, 1150],
#           [ 473,    0]]),
#    'method': 'Clustering'}],
#  53561: [{'accuracy': 0.6506753609687936,
#    'confusion': array([[1150,   40],
#           [ 710,  247]]),
#    'assume_0_accuracy': 0.5542617605961807,
#    'assume_0_confusion': array([[   0, 1190],
#           [ 957,    0]]),
#    'method': 'Clustering'}],
#  53564: [{'accuracy': 0.7906371911573472,
#    'confusion': array([[487,  12],
#           [149, 121]]),
#    'assume_0_accuracy': 0.6488946684005201,
#    'assume_0_confusion': array([[  0, 499],
#           [270,   0]]),
#    'method': 'Clustering'}],
#  53625: [{'accuracy': 0.7658227848101266,
#    'confusion': array([[236,   7],
#           [ 67,   6]]),
#    'assume_0_accuracy': 0.7689873417721519,
#    'assume_0_confusion': array([[  0, 243],
#           [ 73,   0]]),
#    'method': 'Clustering'}],
#  53639: [{'accuracy': 0.8194662480376766,
#    'confusion': array([[518,   1],
#           [114,   4]]),
#    'assume_0_accuracy': 0.814756671899529,
#    'assume_0_confusion': array([[  0, 519],
#           [118,   0]]),
#    'method': 'Clustering'}],
#  53640: [{'accuracy': 0.6820027063599459,
#    'confusion': array([[446,   7],
#           [228,  58]]),
#    'assume_0_accuracy': 0.6129905277401895,
#    'assume_0_confusion': array([[  0, 453],
#           [286,   0]]),
#    'method': 'Clustering'}],
#  53648: [{'accuracy': 0.8455772113943029,
#    'confusion': array([[526,   2],
#           [101,  38]]),
#    'assume_0_accuracy': 0.7916041979010495,
#    'assume_0_confusion': array([[  0, 528],
#           [139,   0]]),
#    'method': 'Clustering'}],
#  53654: [{'accuracy': 0.9513358778625954,
#    'confusion': array([[   4,    6],
#           [  96, 1990]]),
#    'assume_0_accuracy': 0.9952290076335878,
#    'assume_0_confusion': array([[  10,    0],
#           [   0, 2086]]),
#    'method': 'Clustering'}],
#  53665: [{'accuracy': 0.6752136752136753,
#    'confusion': array([[421,   5],
#           [223,  53]]),
#    'assume_0_accuracy': 0.6068376068376069,
#    'assume_0_confusion': array([[  0, 426],
#           [276,   0]]),
#    'method': 'Clustering'}],
#  53669: [{'accuracy': 0.625,
#    'confusion': array([[452,  17],
#           [283,  48]]),
#    'assume_0_accuracy': 0.5862499999999999,
#    'assume_0_confusion': array([[  0, 469],
#           [331,   0]]),
#    'method': 'Clustering'}],
#  53678: [{'accuracy': 0.9450915141430949,
#    'confusion': array([[549,  16],
#           [ 17,  19]]),
#    'assume_0_accuracy': 0.940099833610649,
#    'assume_0_confusion': array([[  0, 565],
#           [ 36,   0]]),
#    'method': 'Clustering'}],
#  53700: [{'accuracy': 0.8303886925795053,
#    'confusion': array([[915,   3],
#           [189,  25]]),
#    'assume_0_accuracy': 0.8109540636042403,
#    'assume_0_confusion': array([[  0, 918],
#           [214,   0]]),
#    'method': 'Clustering'}],
#  53711: [{'accuracy': 0.7666666666666666,
#    'confusion': array([[108,   0],
#           [ 35,   7]]),
#    'assume_0_accuracy': 0.72,
#    'assume_0_confusion': array([[  0, 108],
#           [ 42,   0]]),
#    'method': 'Clustering'}],
#  ...}

# %%
eps = results_dict.keys()
cluster_confusion = np.array([[0, 0], [0, 0]])
host_confusion = np.array([[0, 0], [0, 0]])

cluster_accuracy = 0
host_accuracy = 0

for e in eps:
    cluster = results_dict[e][0]
    host = results_dict[e][1]
    cluster_confusion += cluster['confusion']
    host_confusion += host['confusion']

    cluster_accuracy += cluster['accuracy']
    host_accuracy += host['accuracy']
# results_dict[421][0]['confusion']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 10
#       8 for e in eps:
#       9     cluster = results_dict[e][0]
# ---> 10     host = results_dict[e][1]
#      11     cluster_confusion += cluster['confusion']
#      12     host_confusion += host['confusion']
#
# IndexError: list index out of range

# %%
confusion
# Out:
# array([[2218502,   45055],
#        [ 713701,  242908]])
